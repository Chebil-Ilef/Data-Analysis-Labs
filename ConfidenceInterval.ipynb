# %%
import numpy as np
import matplotlib.pyplot as plt

# Given data
data = [1.23, 0.49, 0.49, 1.08, 0.59, 0.28, 0.18, 0.1,
        0.94, 1.33, 0.19, 1.16, 0.98, 0.34, 0.34, 0.19,
        0.21, 0.4, 0.04, 0.83, 0.05, 0.63, 0.34, 0.75,
        0.04, 0.86, 0.43, 0.044, 0.81, 0.15, 0.56, 0.84]

# 1. Data Representation: Histogram
plt.hist(data, bins=10, color='skyblue', edgecolor='black')
plt.title('Mercury Concentration in Fish Muscle Tissue')
plt.xlabel('Concentration (ppm)')
plt.ylabel('Frequency')
plt.show()

# 2. Parameter Computation: Sample mean and sample variance
sample_mean = np.mean(data)
sample_variance = np.var(data, ddof=1)  # Use ddof=1 for sample variance

print("Sample Mean:", sample_mean)
print("Sample Variance:", sample_variance)

# 3. Confidence Interval Calculation
population_variance = 0.12
n = len(data)
confidence_level = 0.95
z = 1.96  # Z-value for 95% confidence level

# Calculate margin of error
margin_of_error = z * np.sqrt(population_variance / n)

# Calculate confidence interval
confidence_interval_lower = sample_mean - margin_of_error
confidence_interval_upper = sample_mean + margin_of_error

print("Confidence Interval for Population Mean (95% confidence level):")
print("Lower bound:", confidence_interval_lower)
print("Upper bound:", confidence_interval_upper)
# Out:
# Sample Mean: 0.5279375
# Sample Variance: 0.14739547983870968
# Confidence Interval for Population Mean (95% confidence level):
# Lower bound: 0.4079125026036242
# Upper bound: 0.6479624973963757
